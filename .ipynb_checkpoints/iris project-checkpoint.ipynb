# %% [markdown]
# # NICHOLAS MUCHIRI KINYUA

# %% [markdown]
# # Iris Flower Classification

# %% [markdown]
# ![iris flowers.jpeg](attachment:b4b3cdd7-2d92-4435-8567-03368980dc5a.jpeg)

# %% [markdown]
# # Table of contents
# [1. Data Understanding](#1.-Data-Understanding) </br>
# [1.1 Task](#1.1-Task) </br>
# [1.2 Problem Statement](#1.2-Problem-Statement) </br>
# [1.3 Main Objective](#1.3-Main-Objective) </br>
# [1.4 Specific Objectives](#1.4-Specific-Objectives) </br>
# [2.Data Description](#2.-Data-Description) </br>
# [3. Importing Libraries And Warnings](#3.-Importing-Libraries-And-Warnings) </br>
# [4. Data Understanding](#4.-Data-Understanding) </br>
# [4.1. Loading The Data](#4.1-Loading-The-Data) </br>
# [5. Data Preparation](#5.-Data-Preparation) </br>
# [5.1. Checking For Missing Values](#5.1-Checking-For-Missing-Values)</br>
# [5.2 Handling Missing Values](#5.2-Handling-Missing-Values)</br>
# [5.3 Checking For Duplicates](#5.3-Checking-For-Duplicates)</br>
# [5.4 Checking For Placeholders](#5.4-Checking-For-Placeholders)</br>
# [5.5 Removing Whitespace](#5.5-Removing-Whitespace)</br>
# [5.6 Outliers](#5.6-Outliers)</br>
# [6. EDA](#6.-EDA) </br>
# [7. Data Preprocessing](#7.-Data-Preprocessing) </br>
# [7.1 Performing Train Test Split](#7.1-Performing-Train-Test-Split) </br>
# [7.2 Class Imbalance](#7.2-Class-Imbalance) </br>
# [8. Data Modelling](#8.-Data-Modelling) </br>
# [8.1 SVM](#8.1-SVM) </br>
# [9. Evaluation](#9.-Evaluation) </br>
# [10. Conclusions](#10.-Conclusions) </br>
# [11. Recommendations](#11.-Recommendations)

# %% [markdown]
# # 1. Business Understanding

# %% [markdown]
# ## 1.1 Task
#
# Classify iris flowers into three species (setosa, versicolor, virginica) based on
#
# sepal length, </br>
# sepal width, </br>
# petal length, </br>
# petal width.

# %% [markdown]
# # 1.2 Problem Statement

# %% [markdown]
# To develop a model that can accurately classify iris flowers into their respective species based on their physical characteristics.

# %% [markdown]
# # 1.3 Main Objective

# %% [markdown]
# I will build a supervised learning model/models (now that I have the targets) that can learn from the provided dataset containing measurements of iris flowers.

# %% [markdown]
# # 1.4 Specific Objectives

# %% [markdown]
# ### Classification:
# I will build a model that can accurately classify Iris flowers into their three known species (Iris Setosa, Iris Versicolor, Iris Virginica) based on the provided measurements. This will involve learning the patterns i.e The model needs to identify the relationships between the flower measurements (sepal and petal dimensions) and the corresponding species.
# ### Evaluation:
# A key aspect of evaluation will be to compare the classification accuracy achieved using PCA. This will help me understand if dimensionality reduction through PCA benefits the model performance in this specific case.

# %% [markdown]
# # 2. Data Description

# %% [markdown]
# I got the iris dataset from Kaggle, a popular datasets website.
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id </br>
# SepalLengthCm </br>
# SepalWidthCm </br>
# PetalLengthCm </br>
# PetalWidthCm </br>
# Species

# %% [markdown]
# # 3. Importing Libraries And Warnings

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.svm import SVC
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 4. Data Understanding

# %% [markdown]
# ## 4.1 Loading The Data

# %%
# loading the data uing pandas and assigning it a variable data
data = pd.read_csv("Data/Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.shape
# Out:
# (150, 6)

# %% [markdown]
# The dataset, Iris, has got 150 rows and 6 columns.
# columns ae as follows: </br>
# Id - The primary identifier </br>
# SepalLengthCm - length of the sepal in centimeters </br>
# SepalWidthCm - width of the sepal in centimeters </br>
# PetalLengthCm - length of the petal in centimeters </br>
# PetalWidthCm - width of the petal in centimeters </br>
# Species - The target amking this project a supervised machine learning project.

# %% [markdown]
# ## 4.2 Checking For Missing Values

# %%
# Missing values
data.isna()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
# Sum of missing values
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Since there are no missing values, we move forward to duplicates

# %% [markdown]
# ## 4.3 Checking For Duplicates

# %%
# Duplicates
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
#Sum of duplicates
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Since there are no missing values, we move forward to outliers

# %% [markdown]
# ## 4.4 Outliers

# %%
# Function to detect any outliers
def detect_outliers_iqr(data, features):
    outlier_indices = {}
    
    for feature in features:
        Q1 = data[feature].quantile(0.25)
        Q3 = data[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outlier_indices[feature] = data[(data[feature] < lower_bound) | (data[feature] > upper_bound)].index.tolist()
        
    return outlier_indices

# %%
#Checking in each column for outliers
outlier_indices = detect_outliers_iqr(data, ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])

# Print the results
for feature, indices in outlier_indices.items():
    print(f"Outliers in {feature}: {indices}")
# Out:
# Outliers in SepalLengthCm: []
# Outliers in SepalWidthCm: [15, 32, 33, 60]
# Outliers in PetalLengthCm: []
# Outliers in PetalWidthCm: []

# %% [markdown]
# It seems SepalWidthCm has values which divert significantly from the rest of the values.

# %%
#Creating a new dataset without outliers
cleaned_data = data.drop(outlier_indices['SepalWidthCm'])
cleaned_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#For the purposes of simplicity
data = cleaned_data
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Now that we have clean data, we are good to go

# %% [markdown]
# # 6. EDA

# %% [markdown]
# ## 6.1 Univariate Analysis

# %% [markdown]
# SepalLengthCm

# %%
x = data["SepalLengthCm"]

plt.figure(figsize = (10, 6))

plt.hist(x)

plt.title("SepalLengthCm")
plt.ylabel("Frequency of the bins")
plt.xlabel("length in cm")
plt.show()

# %% [markdown]
# SepalWidthCm

# %%
x = data["SepalWidthCm"]

plt.figure(figsize = (10, 6))

plt.hist(x)

plt.title("SepalWidthCm")
plt.ylabel("Frequency of the bins")
plt.xlabel("length in cm")
plt.show()

# %% [markdown]
# PetalLengthCm

# %%
x = data["PetalLengthCm"]

plt.figure(figsize = (10, 6))

plt.hist(x)

plt.title("PetalLengthCm")
plt.ylabel("Frequency of the bins")
plt.xlabel("length in cm")
plt.show()

# %% [markdown]
# PetalWidthCm

# %%
x = data["PetalWidthCm"]

plt.figure(figsize = (10, 6))

plt.hist(x)

plt.title("PetalWidthCm")
plt.ylabel("Frequency of the bins")
plt.xlabel("Length in Cm")
plt.show()

# %% [markdown]
# ## 6.2 Bivariate Analysis

# %% [markdown]
# SepalLengthCm vs SepalWidthCm

# %%
plt.figure(figsize = (10, 6))

plt.plot(data["SepalLengthCm"], color = "blue")
plt.plot(data["SepalWidthCm"])

plt.title("SepalLengthCm vs SepalWidthCm")
plt.ylabel("Frequency of the bins")
plt.xlabel("Length in Cm")
plt.show()

# %% [markdown]
# PetalLegthCm vs PetalWidthCm

# %%
plt.figure(figsize = (10, 6))

plt.plot(data["PetalLengthCm"], color = "blue")
plt.plot(data["PetalWidthCm"])

plt.title("PetalLegthCm vs PetalWidthCm")
plt.ylabel("Frequency of the bins")
plt.xlabel("Length in Cm")
plt.show()

# %%
# Set up figure and axes
fig, axes = plt.subplots(ncols=4, figsize=(15,4))

# Loop over each feature
# Exclude column 1 i.e id and the last column; species.
for feature_index, feature_name in enumerate(data.columns[1:-1]):
    
    # Find the relevant axes from the list and give it a label
    axes[feature_index].set_xlabel(feature_name)
    
    # Loop over the three target values and plot them by color
    colors = ["r", "g", "b"]
    for target_name, color in zip(data['Species'].unique(), colors):
        subset_rows = data[data["Species"] == target_name]
        axes[feature_index].hist(
            subset_rows[feature_name],
            label=target_name,    
            color=color,
            alpha=0.5
        )
        
# Add a legend to the last axes only
axes[-1].legend()

# Set a title for the overall plot
plt.suptitle("Feature Distributions by Iris Type")

plt.show()

# %% [markdown]
# ## 6.3 Multivariate Analysis

# %%
plt.figure(figsize=(10, 6))

# Plot data points with different colors based on species
plt.scatter(data[data["Species"] == "Iris-setosa"]["PetalLengthCm"], 
            data[data["Species"] == "Iris-setosa"]["PetalWidthCm"], 
            color = "blue", label = "Setosa")
plt.scatter(data[data["Species"] == "Iris-versicolor"]["PetalLengthCm"], 
            data[data["Species"] == "Iris-versicolor"]["PetalWidthCm"], 
            color = "red", label = "Versicolor")
plt.scatter(data[data["Species"] == "Iris-virginica"]["PetalLengthCm"], 
            data[data["Species"] == "Iris-virginica"]["PetalWidthCm"], 
            color = "green", label = "Virginica")

plt.title("Petal Width vs. Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plot data points with different colors based on species
plt.scatter(data[data["Species"] == "Iris-setosa"]["SepalLengthCm"], 
            data[data["Species"] == "Iris-setosa"]["SepalWidthCm"], 
            color = "blue", label = "Setosa")
plt.scatter(data[data["Species"] == "Iris-versicolor"]["SepalLengthCm"], 
            data[data["Species"] == "Iris-versicolor"]["SepalWidthCm"], 
            color = "red", label = "Versicolor")
plt.scatter(data[data["Species"] == "Iris-virginica"]["SepalLengthCm"], 
            data[data["Species"] == "Iris-virginica"]["SepalWidthCm"], 
            color = "green", label = "Virginica")

plt.title("Sepal Width vs. Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()

plt.show()

# %% [markdown]
# # 7. Data Preprocessing

# %% [markdown]
# ## 7.1 Performing Train Test Split

# %%
# Separate X and y
X = data.drop(columns = "Species")
y = data["Species"]

# Perform train-test split with random_state=42
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## 7.2 Scaling

# %%
# Instantiate a scaler
scaler = StandardScaler()

# Fit the scaler on X_train
scaler.fit(X_train)

# Transform X_train and X_test
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Now the values should be scaled
pd.DataFrame(X_train_scaled).head()
# Out:
#           0         1         2         3         4
# 0  0.252798 -0.331669 -0.045973  0.113506  0.066337
# 1 -0.127927  0.492642 -1.298730  0.584825  0.344444
# 2 -0.556243  0.728159 -0.547076  0.408080  0.344444
# 3  1.466359  1.199194  0.204579  0.879399  1.178765
# 4  1.442564  0.139366 -0.045973  0.525910  0.761605

# %% [markdown]
# ## 7.3 PCA

# %%
# Instantiate the PCA transformer with n_components=2
pca = PCA(n_components=2)

# Fit PCA on the scaled training data and transform both training and test data
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
# Create a DataFrame for the transformed PCA data
train_combined_pca = pd.DataFrame(X_train_pca, columns=["PC 1", "PC 2"])
train_combined_pca["target"] = y_train.values
train_combined_pca
# Out:
#          PC 1      PC 2           target
# 0   -0.070925 -0.167287  Iris-versicolor
# 1   -0.866912 -1.011292  Iris-versicolor
# 2   -0.545587 -0.202843  Iris-versicolor
# 3   -2.277068  0.589944   Iris-virginica
# 4   -1.428872 -0.034637   Iris-virginica
# ..        ...       ...              ...
# 104 -0.622516  0.265845  Iris-versicolor
# 105 -1.522038  0.695555   Iris-virginica
# 106  2.769860  2.258284      Iris-setosa
# 107 -0.290885 -0.372422  Iris-versicolor
# 108 -0.522904 -1.613536   Iris-virginica
#
# [109 rows x 3 columns]

# %%
# Set up figure and axes
plt.figure(figsize=(10, 8))
plt.grid()

# Scatter plot of the transformed PCA data
for species in data["Species"].unique():
    plt.scatter(train_combined_pca[train_combined_pca["target"] == species]["PC 1"], 
                train_combined_pca[train_combined_pca["target"] == species]["PC 2"], 
                label=species)

# Customize labels
plt.xlabel('First Principal Component', fontsize=15)
plt.ylabel('Second Principal Component', fontsize=15)
plt.title('Principal Component Analysis (2 PCs) for Iris Dataset', fontsize=20)
plt.legend(fontsize="large")

plt.show()

# %% [markdown]
# # 8. Data Modelling

# %% [markdown]
# ## 8.1 SVM

# %% [markdown]
# # 9. Evaluation

# %% [markdown]
# # 10. Conclusions

# %% [markdown]
# # 11. Recommendations
